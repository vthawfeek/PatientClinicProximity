# %% [markdown]
# ### Installations

# %%
# !pip install geopandas
# !pip install geopy
# !pip install pgeocode
# !pip install PyGeodesy
# !pip install pyopenssl ndg-httpsclient pyasn1

# %% [markdown]
# ### Import data

# %%
# import libraries
import pandas as pd
import numpy as np
import os
import json

# set path
notebook_path = os.path.abspath('Patient_Clinic_Proximity_Finder.ipynb')
path = notebook_path.rsplit('/',1)[0]

# read data files
patient_data = pd.read_csv(path+'/'+'patients.csv')
clinic_data = pd.read_csv(path+'/'+'clinics.csv')

# read config file
with open('config.json') as config_file:
    cf = json.load(config_file)

# %%
patient_data = patient_data.head(10).copy(deep=True)
clinic_data = clinic_data.head(10).copy(deep=True)

# %%
pat_incomp_entry = {'ID':21,'Address':'random1','Postal Code':'VX1 6L5','FSA':'VX1','City':'Victoria','Province':'BC'}
clin_incomp_entry = {'Clinic ID':21,'Clinic Name':'random1','Clinic Address':'random1','Postal Code':'J4£ 2X1','FSA':'J4£','Clinic City':'Calgary','Province':'AB'}

patient_data = patient_data.append(pat_incomp_entry,ignore_index=True)
clinic_data = clinic_data.append(clin_incomp_entry,ignore_index=True)

# %%
patient_data

# %%
clinic_data

# %% [markdown]
# ### Map geo co-ordinates

# %%
# import libraries
import pgeocode as geo
from geopy.exc import GeocoderTimedOut
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import re

# geopy requirements
locator = Nominatim(user_agent="topcoder")
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

#pgeocode requirements
country = 'ca'
nomi = geo.Nominatim('ca')

def latlon_with_address(ad,cy):
    try:
        r = locator.geocode(ad+' '+cy)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    return r

def latlon_with_street(ad,cy):
    street = re.split('UNIT | SUITE',ad,flags=re.I)[0]
    try:
        r = locator.geocode(street+' '+cy)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    return r

def latlon_with_elim_address(ad,cy):
    add_str = re.split(' |-',ad)
    for i in range(len(add_str)-1):
        sub_str = ' '.join(add_str[:-(i+1)])
        try:
            r = locator.geocode(sub_str+' '+cy)
            if r!=None:
                break
        except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
            print(f"Error: {e}")
            r = 'No response'
    return r

def latlon_with_fsa(pc):
    try:
        r = nomi.query_postal_code(pc)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    return r

def latlon_with_error_fsa(pc):
    fsa = pc.split(' ')[0]
    all_fsa = list(patient_data['FSA'])+list(clinic_data['FSA'])
    all_fsa.remove(fsa)
    for i in [1,2]:
        for j in all_fsa:
            if fsa[0:len(fsa)-i] in j:
                pc = j
                break
        else:
            continue
        break
    try:
        r = nomi.query_postal_code(pc)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    return r

def lat_long_finder(ad,cy,pc):
    c = 0
    res = latlon_with_address(ad,cy)
    #print('1',type(res))
    if res is None or type(res) is str:
        res = latlon_with_street(ad,cy)
        #print('2',type(res))
        if res is None or type(res) is str:
            res = latlon_with_elim_address(ad,cy)
            #print('3',type(res))
            if res is None or type(res) is str:
                res = latlon_with_fsa(pc)
                #print('4',type(res))
                c+=1
                if res is None or type(res) is str:
                    res = latlon_with_error_fsa(pc)
                    #print('5',type(res))
                    c+=1
    if c==0: return [res.point[0],res.point[1]]
    else: return [res['latitude'],res['longitude']]

# append patient_data
pat_lat = []
pat_lon = []
for index,row in patient_data.iterrows():
    print(f"Fraction completed: {index}/{patient_data.shape[0]+clinic_data.shape[0]}")
    lap = lat_long_finder(row['Address'],row['City'],row['Postal Code'])[0]
    lop = lat_long_finder(row['Address'],row['City'],row['Postal Code'])[1]
    pat_lat.append(lap)
    pat_lon.append(lop)
    
patient_data['Latitude'] = pat_lat
patient_data['Longitude'] = pat_lon
patient_data['Geocode'] = '"'+patient_data['Latitude'].astype(str)+','+patient_data['Longitude'].astype(str)+'"'

# append clinic_data
clin_lat = []
clin_lon = []
for index,row in clinic_data.iterrows():
    print(f"Fraction: {patient_data.shape[0]+index}/{patient_data.shape[0]+clinic_data.shape[0]}")
    lac = lat_long_finder(row['Clinic Address'],row['Clinic City'],row['Postal Code'])[0]
    loc = lat_long_finder(row['Clinic Address'],row['Clinic City'],row['Postal Code'])[1]
    clin_lat.append(lac)
    clin_lon.append(loc)

clinic_data['Latitude'] = clin_lat
clinic_data['Longitude'] = clin_lon
clinic_data['Geocode'] = '"'+clinic_data['Latitude'].astype(str)+','+clinic_data['Longitude'].astype(str)+'"'
# Out:
# Fraction completed: 0/600
# Fraction completed: 1/600
# Fraction completed: 2/600
# Fraction completed: 3/600
# Fraction completed: 4/600
# Fraction completed: 5/600
# Fraction completed: 6/600
# Fraction completed: 7/600
# Fraction completed: 8/600
# Fraction completed: 9/600
# Fraction completed: 10/600
# Fraction completed: 11/600
# Fraction completed: 12/600
# Fraction completed: 13/600
# Fraction completed: 14/600
# Fraction completed: 15/600
# Fraction completed: 16/600
# Fraction completed: 17/600
# Fraction completed: 18/600
# Fraction completed: 19/600
# Fraction completed: 20/600
# Fraction completed: 21/600
# Fraction completed: 22/600
# Fraction completed: 23/600
# Fraction completed: 24/600
# Fraction completed: 25/600
# Fraction completed: 26/600
# Fraction completed: 27/600
# Fraction completed: 28/600
# Fraction completed: 29/600
# Fraction completed: 30/600
# Fraction completed: 31/600
# Fraction completed: 32/600
# Fraction completed: 33/600
# Fraction completed: 34/600
# Fraction completed: 35/600
# Fraction completed: 36/600
# Fraction completed: 37/600
# Fraction completed: 38/600
# Fraction completed: 39/600
# Fraction completed: 40/600
# Fraction completed: 41/600
# Fraction completed: 42/600
# Fraction completed: 43/600
# Fraction completed: 44/600
# Fraction completed: 45/600
# Fraction completed: 46/600
# Fraction completed: 47/600
# Fraction completed: 48/600
# Fraction completed: 49/600
# Fraction completed: 50/600
# Fraction completed: 51/600
# Fraction completed: 52/600
# Fraction completed: 53/600
# Fraction completed: 54/600
# Fraction completed: 55/600
# Fraction completed: 56/600
# Fraction completed: 57/600
# Fraction completed: 58/600
# Fraction completed: 59/600
# Fraction completed: 60/600
# Fraction completed: 61/600
# Fraction completed: 62/600
# Fraction completed: 63/600
# Fraction completed: 64/600
# Fraction completed: 65/600
# Fraction completed: 66/600
# Fraction completed: 67/600
# Fraction completed: 68/600
# Fraction completed: 69/600
# Fraction completed: 70/600
# Fraction completed: 71/600
# Fraction completed: 72/600
# Fraction completed: 73/600
# Fraction completed: 74/600
# Fraction completed: 75/600
# Fraction completed: 76/600
# Fraction completed: 77/600
# Fraction completed: 78/600
# Fraction completed: 79/600
# Fraction completed: 80/600
# Fraction completed: 81/600
# Fraction completed: 82/600
# Fraction completed: 83/600
# Fraction completed: 84/600
# Fraction completed: 85/600
# Fraction completed: 86/600
# Fraction completed: 87/600
# Fraction completed: 88/600
# Fraction completed: 89/600
# Fraction completed: 90/600
# Fraction completed: 91/600
# Fraction completed: 92/600
# Fraction completed: 93/600
# Fraction completed: 94/600
# Fraction completed: 95/600
# Fraction completed: 96/600
# Fraction completed: 97/600
# Fraction completed: 98/600
# Fraction completed: 99/600
# Fraction completed: 100/600
# Fraction completed: 101/600
# Fraction completed: 102/600
# Fraction completed: 103/600
# Fraction completed: 104/600
# Fraction completed: 105/600
# Fraction completed: 106/600
# Fraction completed: 107/600
# Fraction completed: 108/600
# Fraction completed: 109/600
# Fraction completed: 110/600
# Fraction completed: 111/600
# Fraction completed: 112/600
# Fraction completed: 113/600
# Fraction completed: 114/600
# Fraction completed: 115/600
# Fraction completed: 116/600
# Fraction completed: 117/600
# Fraction completed: 118/600
# Fraction completed: 119/600
# Fraction completed: 120/600
# Fraction completed: 121/600
# Fraction completed: 122/600
# Fraction completed: 123/600
# Fraction completed: 124/600
# Fraction completed: 125/600
# Fraction completed: 126/600
# Fraction completed: 127/600
# Fraction completed: 128/600
# Fraction completed: 129/600
# Fraction completed: 130/600
# Fraction completed: 131/600
# Fraction completed: 132/600
# Fraction completed: 133/600
# Fraction completed: 134/600
# Fraction completed: 135/600
# Fraction completed: 136/600
# Fraction completed: 137/600
# Fraction completed: 138/600
# Fraction completed: 139/600
# Fraction completed: 140/600
# Fraction completed: 141/600
# Fraction completed: 142/600
# Fraction completed: 143/600
# Fraction completed: 144/600
# Fraction completed: 145/600
# Fraction completed: 146/600
# Fraction completed: 147/600
# Fraction completed: 148/600
# Fraction completed: 149/600
# Fraction completed: 150/600
# Fraction completed: 151/600
# Fraction completed: 152/600
# Fraction completed: 153/600
# Fraction completed: 154/600
# Fraction completed: 155/600
# Fraction completed: 156/600
# Fraction completed: 157/600
# Fraction completed: 158/600
# Fraction completed: 159/600
# Fraction completed: 160/600
# Fraction completed: 161/600
# Fraction completed: 162/600
# Fraction completed: 163/600
# Fraction completed: 164/600
# Fraction completed: 165/600
# Fraction completed: 166/600
# Fraction completed: 167/600
# Fraction completed: 168/600
# Fraction completed: 169/600
# Fraction completed: 170/600
# Fraction completed: 171/600
# Fraction completed: 172/600
# Fraction completed: 173/600
# Fraction completed: 174/600
# Fraction completed: 175/600
# Fraction completed: 176/600
# Fraction completed: 177/600
# Fraction completed: 178/600
# Fraction completed: 179/600
# Fraction completed: 180/600
# Fraction completed: 181/600
# Fraction completed: 182/600
# Fraction completed: 183/600
# Fraction completed: 184/600
# Fraction completed: 185/600
# Fraction completed: 186/600
# Fraction completed: 187/600
# Fraction completed: 188/600
# Fraction completed: 189/600
# Fraction completed: 190/600
# Fraction completed: 191/600
# Fraction completed: 192/600
# Fraction completed: 193/600
# Fraction completed: 194/600
# Fraction completed: 195/600
# Fraction completed: 196/600
# Fraction completed: 197/600
# Fraction completed: 198/600
# Fraction completed: 199/600
# Fraction completed: 200/600
# Fraction completed: 201/600
# Fraction completed: 202/600
# Fraction completed: 203/600
# Fraction completed: 204/600
# Fraction completed: 205/600
# Fraction completed: 206/600
# Fraction completed: 207/600
# Fraction completed: 208/600
# Fraction completed: 209/600
# Fraction completed: 210/600
# Fraction completed: 211/600
# Fraction completed: 212/600
# Fraction completed: 213/600
# Fraction completed: 214/600
# Fraction completed: 215/600
# Fraction completed: 216/600
# Fraction completed: 217/600
# Fraction completed: 218/600
# Fraction completed: 219/600
# Fraction completed: 220/600
# Fraction completed: 221/600
# Fraction completed: 222/600
# Fraction completed: 223/600
# Fraction completed: 224/600
# Fraction completed: 225/600
# Fraction completed: 226/600
# Fraction completed: 227/600
# Fraction completed: 228/600
# Fraction completed: 229/600
# Fraction completed: 230/600
# Fraction completed: 231/600
# Fraction completed: 232/600
# Fraction completed: 233/600
# Fraction completed: 234/600
# Fraction completed: 235/600
# Fraction completed: 236/600
# Fraction completed: 237/600
# Fraction completed: 238/600
# Fraction completed: 239/600
# Fraction completed: 240/600
# Fraction completed: 241/600
# Fraction completed: 242/600
# Fraction completed: 243/600
# Fraction completed: 244/600
# Fraction completed: 245/600
# Fraction completed: 246/600
# Fraction completed: 247/600
# Fraction completed: 248/600
# Fraction completed: 249/600
# Fraction completed: 250/600
# Fraction completed: 251/600
# Fraction completed: 252/600
# Fraction completed: 253/600
# Fraction completed: 254/600
# Fraction completed: 255/600
# Fraction completed: 256/600
# Fraction completed: 257/600
# Fraction completed: 258/600
# Fraction completed: 259/600
# Fraction completed: 260/600
# Fraction completed: 261/600
# Fraction completed: 262/600
# Fraction completed: 263/600
# Fraction completed: 264/600
# Fraction completed: 265/600
# Fraction completed: 266/600
# Fraction completed: 267/600
# Fraction completed: 268/600
# Fraction completed: 269/600
# Fraction completed: 270/600
# Fraction completed: 271/600
# Fraction completed: 272/600
# Fraction completed: 273/600
# Fraction completed: 274/600
# Fraction completed: 275/600
# Fraction completed: 276/600
# Fraction completed: 277/600
# Fraction completed: 278/600
# Fraction completed: 279/600
# Fraction completed: 280/600
# Fraction completed: 281/600
# Fraction completed: 282/600
# Fraction completed: 283/600
# Fraction completed: 284/600
# Fraction completed: 285/600
# Fraction completed: 286/600
# Fraction completed: 287/600
# Fraction completed: 288/600
# Fraction completed: 289/600
# Fraction completed: 290/600
# Fraction completed: 291/600
# Fraction completed: 292/600
# Fraction completed: 293/600
# Fraction completed: 294/600
# Fraction completed: 295/600
# Fraction completed: 296/600
# Fraction completed: 297/600
# Fraction completed: 298/600
# Fraction completed: 299/600
# Fraction completed: 300/600
# Fraction completed: 301/600
# Fraction completed: 302/600
# Fraction completed: 303/600
# Fraction completed: 304/600
# Fraction completed: 305/600
# Fraction completed: 306/600
# Fraction completed: 307/600
# Fraction completed: 308/600
# Fraction completed: 309/600
# Fraction completed: 310/600
# Fraction completed: 311/600
# Fraction completed: 312/600
# Fraction completed: 313/600
# Fraction completed: 314/600
# Fraction completed: 315/600
# Fraction completed: 316/600
# Fraction completed: 317/600
# Fraction completed: 318/600
# Fraction completed: 319/600
# Fraction completed: 320/600
# Fraction completed: 321/600
# Fraction completed: 322/600
# Fraction completed: 323/600
# Fraction completed: 324/600
# Fraction completed: 325/600
# Fraction completed: 326/600
# Fraction completed: 327/600
# Fraction completed: 328/600
# Fraction completed: 329/600
# Fraction completed: 330/600
# Fraction completed: 331/600
# Fraction completed: 332/600
# Fraction completed: 333/600
# Fraction completed: 334/600
# Fraction completed: 335/600
# Fraction completed: 336/600
# Fraction completed: 337/600
# Fraction completed: 338/600
# Fraction completed: 339/600
# Fraction completed: 340/600
# Fraction completed: 341/600
# Fraction completed: 342/600
# Fraction completed: 343/600
# Fraction completed: 344/600
# Fraction completed: 345/600
# Fraction completed: 346/600
# Fraction completed: 347/600
# Fraction completed: 348/600
# Fraction completed: 349/600
# Fraction completed: 350/600
# Fraction completed: 351/600
# Fraction completed: 352/600
# Fraction completed: 353/600
# Fraction completed: 354/600
# Fraction completed: 355/600
# Fraction completed: 356/600
# Fraction completed: 357/600
# Fraction completed: 358/600
# Fraction completed: 359/600
# Fraction completed: 360/600
# Fraction completed: 361/600
# Fraction completed: 362/600
# Fraction completed: 363/600
# Fraction completed: 364/600
# Fraction completed: 365/600
# Fraction completed: 366/600
# Fraction completed: 367/600
# Fraction completed: 368/600
# Fraction completed: 369/600
# Fraction completed: 370/600
# Fraction completed: 371/600
# Fraction completed: 372/600
# Fraction completed: 373/600
# Fraction completed: 374/600
# Fraction completed: 375/600
# Fraction completed: 376/600
# Fraction completed: 377/600
# Fraction completed: 378/600
# Fraction completed: 379/600
# Fraction completed: 380/600
# Fraction completed: 381/600
# Fraction completed: 382/600
# Fraction completed: 383/600
# Fraction completed: 384/600
# Fraction completed: 385/600
# Fraction completed: 386/600
# Fraction completed: 387/600
# Fraction completed: 388/600
# Fraction completed: 389/600
# Fraction completed: 390/600
# Fraction completed: 391/600
# Fraction completed: 392/600
# Fraction completed: 393/600
# Fraction completed: 394/600
# Fraction completed: 395/600
# Fraction completed: 396/600
# Fraction completed: 397/600
# Fraction completed: 398/600
# Fraction completed: 399/600
# Fraction completed: 400/600
# Fraction completed: 401/600
# Fraction completed: 402/600
# Fraction completed: 403/600
# Fraction completed: 404/600
# Fraction completed: 405/600
# Fraction completed: 406/600
# Fraction completed: 407/600
# Fraction completed: 408/600
# Fraction completed: 409/600
# Fraction completed: 410/600
# Fraction completed: 411/600
# Fraction completed: 412/600
# Fraction completed: 413/600
# Fraction completed: 414/600
# Fraction completed: 415/600
# Fraction completed: 416/600
# Fraction completed: 417/600
# Fraction completed: 418/600
# Fraction completed: 419/600
# Fraction completed: 420/600
# Fraction completed: 421/600
# Fraction completed: 422/600
# Fraction completed: 423/600
# Fraction completed: 424/600
# Fraction completed: 425/600
# Fraction completed: 426/600
# Fraction completed: 427/600
# Fraction completed: 428/600
# Fraction completed: 429/600
# Fraction completed: 430/600
# Fraction completed: 431/600
# Fraction completed: 432/600
# Fraction completed: 433/600
# Fraction completed: 434/600
# Fraction completed: 435/600
# Fraction completed: 436/600
# Fraction completed: 437/600
# Fraction completed: 438/600
# Fraction completed: 439/600
# Fraction completed: 440/600
# Fraction completed: 441/600
# Fraction completed: 442/600
# Fraction completed: 443/600
# Fraction completed: 444/600
# Fraction completed: 445/600
# Fraction completed: 446/600
# Fraction completed: 447/600
# Fraction completed: 448/600
# Fraction completed: 449/600
# Fraction completed: 450/600
# Fraction completed: 451/600
# Fraction completed: 452/600
# Fraction completed: 453/600
# Fraction completed: 454/600
# Fraction completed: 455/600
# Fraction completed: 456/600
# Fraction completed: 457/600
# Fraction completed: 458/600
# Fraction completed: 459/600
# Fraction completed: 460/600
# Fraction completed: 461/600
# Fraction completed: 462/600
# Fraction completed: 463/600
# Fraction completed: 464/600
# Fraction completed: 465/600
# Fraction completed: 466/600
# Fraction completed: 467/600
# Fraction completed: 468/600
# Fraction completed: 469/600
# Fraction completed: 470/600
# Fraction completed: 471/600
# Fraction completed: 472/600
# Fraction completed: 473/600
# Fraction completed: 474/600
# Fraction completed: 475/600
# Fraction completed: 476/600
# Fraction completed: 477/600
# Fraction completed: 478/600
# Fraction completed: 479/600
# Fraction completed: 480/600
# Fraction completed: 481/600
# Fraction completed: 482/600
# Fraction completed: 483/600
# Fraction completed: 484/600
# Fraction completed: 485/600
# Fraction completed: 486/600
# Fraction completed: 487/600
# Fraction completed: 488/600
# Fraction completed: 489/600
# Fraction completed: 490/600
# Fraction completed: 491/600
# Fraction completed: 492/600
# Fraction completed: 493/600
# Fraction completed: 494/600
# Fraction completed: 495/600
# Fraction completed: 496/600
# Fraction completed: 497/600
# Fraction completed: 498/600
# Fraction completed: 499/600
# Fraction: 500/600
# Fraction: 501/600
# Fraction: 502/600
# Fraction: 503/600
# Fraction: 504/600
# Fraction: 505/600
# Fraction: 506/600
# Fraction: 507/600
# Fraction: 508/600
# Fraction: 509/600
# Fraction: 510/600
# Fraction: 511/600
# Fraction: 512/600
# Fraction: 513/600
# Fraction: 514/600
# Fraction: 515/600
# Fraction: 516/600
# Fraction: 517/600
# Fraction: 518/600
# Fraction: 519/600
# Fraction: 520/600
# Fraction: 521/600
# Fraction: 522/600
# Fraction: 523/600
# Fraction: 524/600
# Fraction: 525/600
# Fraction: 526/600
# Fraction: 527/600
# Fraction: 528/600
# Fraction: 529/600
# Fraction: 530/600
# Fraction: 531/600
# Fraction: 532/600
# Fraction: 533/600
# Fraction: 534/600
# Fraction: 535/600
# Fraction: 536/600
# Fraction: 537/600
# Fraction: 538/600
# Fraction: 539/600
# Fraction: 540/600
# Fraction: 541/600
# Fraction: 542/600
# Fraction: 543/600
# Fraction: 544/600
# Fraction: 545/600
# Fraction: 546/600
# Fraction: 547/600
# Fraction: 548/600
# Fraction: 549/600
# Fraction: 550/600
# Fraction: 551/600
# Fraction: 552/600
# Fraction: 553/600
# Fraction: 554/600
# Fraction: 555/600
# Fraction: 556/600
# Fraction: 557/600
# Fraction: 558/600
# Fraction: 559/600
# Fraction: 560/600
# Fraction: 561/600
# Fraction: 562/600
# Fraction: 563/600
# Fraction: 564/600
# Fraction: 565/600
# Fraction: 566/600
# Fraction: 567/600
# Fraction: 568/600
# Fraction: 569/600
# Fraction: 570/600
# Fraction: 571/600
# Fraction: 572/600
# Fraction: 573/600
# Fraction: 574/600
# Fraction: 575/600
# Fraction: 576/600
# Fraction: 577/600
# Fraction: 578/600
# Fraction: 579/600
# Fraction: 580/600
# Fraction: 581/600
# Fraction: 582/600
# Fraction: 583/600
# Fraction: 584/600
# Fraction: 585/600
# Fraction: 586/600
# Fraction: 587/600
# Fraction: 588/600
# Fraction: 589/600
# Fraction: 590/600
# Fraction: 591/600
# Fraction: 592/600
# Fraction: 593/600
# Fraction: 594/600
# Fraction: 595/600
# Fraction: 596/600
# Fraction: 597/600
# Fraction: 598/600
# Fraction: 599/600

# %%
patient_data.head()

# %%
clinic_data.head()

# %% [markdown]
# ### Calculate distance

# %%
def Val2Key(Dict,Val):
    t = list(Dict.values()).count(Val)
    k = []
    if t>1:
        for i in Dict:
            if Dict[i]==Val:
                k.append(i)
        return k
    else:
        return [list(Dict.keys())[list(Dict.values()).index(Val)]]

# %%
# find area around location of interest

from pygeodesy.ellipsoidalVincenty import LatLon 
import requests
import json
import datetime

to = cf['osrm_timeout']
rad = cf['loc_neighbor_dim']
inc = cf['loc_neighbor_expan']
sam = cf['min_clinic_sample_size']

def driving_dist(pat,clin):
    lat1, lon1 = pat[0], pat[1]
    lat2, lon2 = clin[0],clin[1]
    try:
        #raise requests.exceptions.ConnectionError('Throwing and exception here!')
        r = requests.get(f"http://router.project-osrm.org/route/v1/car/{lon1},{lat1};{lon2},{lat2}?overview=false""",timeout=to)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    if r == 'No response':
        return 10e6
    else:
        try:
            #raise ValueError('this is wrong!')
            routes = json.loads(r.content)
            route_1 = routes.get("routes")
            if route_1 is None:
                route_2 = 10e6
            else:
                route_2 = route_1[0]['distance']
        except ValueError as e:
            print(f"Error: {e}")
            route_2 = 10e6
        return route_2/1000

def neighbour_square(latlon,rad):
    p = LatLon(latlon[0],latlon[1])
    for i in [0,90]:
        deg = i
        d1 = p.destination(rad*1000,deg)
        d2 = p.destination(rad*1000,deg+180)
        if i==0: lat_ran = [d1.lat,d2.lat]
        else: lon_ran = [d1.lon,d2.lon]
    return [lat_ran,lon_ran]

def clinics_in_square(lat_range,lon_range):
    near_clincs = []
    for c in range(clinic_data.shape[0]):
        clin = list(clinic_data.iloc[c][clinic_data.iloc[0].index.isin(['Latitude','Longitude'])])
        if min(lat_range)<=clin[0]<=max(lat_range) and min(lon_range)<=clin[1]<=max(lon_range):
            near_clincs.append(clinic_data.iloc[c]['Clinic ID'])
    return near_clincs

start = datetime.datetime.now()
drive_d = []
for p in range(patient_data.shape[0]):
    print(f"Fraction completed: {p}/{patient_data.shape[0]}")
    #rad = 100
    while True:
        pat = list(patient_data.iloc[p][patient_data.iloc[0].index.isin(['Latitude','Longitude'])])
        lat_range, lon_range = neighbour_square(pat,rad)
        closer_clinics = clinics_in_square(lat_range,lon_range)
        if len(closer_clinics)>=sam: break
        else: rad+=inc

    clin_dist = {}
    for c in closer_clinics:
        clinic = clinic_data[clinic_data['Clinic ID']==c]
        clin = [list(clinic['Latitude'])[0],list(clinic['Longitude'])[0]]
        clin_dist[c] = driving_dist(pat,clin)
    clin_id = Val2Key(clin_dist,min(clin_dist.values()))
    drive_d.append([clin_id[0],min(clin_dist.values())])

print(f"Total runtime: {datetime.datetime.now()-start}")
print(f"Time per patient: {(datetime.datetime.now()-start)/patient_data.shape[0]}")

Clinic_Geoc=clinic_data.set_index('Clinic ID')['Geocode'].to_dict()
Clinic_Add=clinic_data.set_index('Clinic ID')['Clinic Address'].to_dict()
Clinic_PC=clinic_data.set_index('Clinic ID')['Postal Code'].to_dict()
Clinic_FSA=clinic_data.set_index('Clinic ID')['FSA'].to_dict()

clinic_ids = [i[0] for i in drive_d]
clinic_dists = [i[1] for i in drive_d]

Output_dict = {
    'Patient_ID': list(patient_data['ID']),
    'Pat_Geo_Cols': ['"Address,City,Postal Code,FSA"']*patient_data.shape[0],
    'Pat_Geocode': list(patient_data['Geocode']),
    'Pat_Address': list(patient_data['Address']),
    'Pat_Postal_Code': list(patient_data['Postal Code']),
    'Pat_FSA': list(patient_data['FSA']),
    'Nearest_Clinic_ID': clinic_ids,
    'Clinic_Geo_Cols': ['"Clinic Address,Clinic City,Postal Code,FSA"']*patient_data.shape[0],
    'Clinic_Geocode': [Clinic_Geoc[i] for i in clinic_ids],
    'Clinic_Address': [Clinic_Add[i] for i in clinic_ids],
    'Clinic_Postal_Code': [Clinic_PC[i] for i in clinic_ids],
    'Clinic_FSA': [Clinic_FSA[i] for i in clinic_ids],
    'Clinic_Distance': [f'"Clinic ID: {i[0]}, Distance: {i[1]} km"' for i in drive_d]
}


df = pd.DataFrame(Output_dict)

#write outout to file
df.to_csv(path+'/'+'Output.csv',index=False,header=True)
# Out:
# Fraction completed: 0/500
# Fraction completed: 1/500
# Fraction completed: 2/500
# Fraction completed: 3/500
# Fraction completed: 4/500
# Fraction completed: 5/500
# Fraction completed: 6/500
# Fraction completed: 7/500
# Fraction completed: 8/500
# Fraction completed: 9/500
# Fraction completed: 10/500
# Fraction completed: 11/500
# Fraction completed: 12/500
# Fraction completed: 13/500
# Fraction completed: 14/500
# Fraction completed: 15/500
# Fraction completed: 16/500
# Fraction completed: 17/500
# Fraction completed: 18/500
# Fraction completed: 19/500
# Fraction completed: 20/500
# Fraction completed: 21/500
# Fraction completed: 22/500
# Fraction completed: 23/500
# Fraction completed: 24/500
# Fraction completed: 25/500
# Fraction completed: 26/500
# Fraction completed: 27/500
# Fraction completed: 28/500
# Fraction completed: 29/500
# Fraction completed: 30/500
# Fraction completed: 31/500
# Fraction completed: 32/500
# Fraction completed: 33/500
# Fraction completed: 34/500
# Fraction completed: 35/500
# Fraction completed: 36/500
# Fraction completed: 37/500
# Fraction completed: 38/500
# Fraction completed: 39/500
# Fraction completed: 40/500
# Fraction completed: 41/500
# Fraction completed: 42/500
# Fraction completed: 43/500
# Fraction completed: 44/500
# Fraction completed: 45/500
# Fraction completed: 46/500
# Fraction completed: 47/500
# Fraction completed: 48/500
# Fraction completed: 49/500
# Fraction completed: 50/500
# Fraction completed: 51/500
# Fraction completed: 52/500
# Fraction completed: 53/500
# Fraction completed: 54/500
# Fraction completed: 55/500
# Fraction completed: 56/500
# Fraction completed: 57/500
# Fraction completed: 58/500
# Fraction completed: 59/500
# Fraction completed: 60/500
# Fraction completed: 61/500
# Fraction completed: 62/500
# Fraction completed: 63/500
# Fraction completed: 64/500
# Fraction completed: 65/500
# Fraction completed: 66/500
# Fraction completed: 67/500
# Fraction completed: 68/500
# Fraction completed: 69/500
# Fraction completed: 70/500
# Fraction completed: 71/500
# Fraction completed: 72/500
# Fraction completed: 73/500
# Fraction completed: 74/500
# Fraction completed: 75/500
# Fraction completed: 76/500
# Fraction completed: 77/500
# Fraction completed: 78/500
# Fraction completed: 79/500
# Fraction completed: 80/500
# Fraction completed: 81/500
# Fraction completed: 82/500
# Fraction completed: 83/500
# Fraction completed: 84/500
# Fraction completed: 85/500
# Fraction completed: 86/500
# Fraction completed: 87/500
# Fraction completed: 88/500
# Fraction completed: 89/500
# Fraction completed: 90/500
# Fraction completed: 91/500
# Fraction completed: 92/500
# Fraction completed: 93/500
# Fraction completed: 94/500
# Fraction completed: 95/500
# Fraction completed: 96/500
# Fraction completed: 97/500
# Fraction completed: 98/500
# Fraction completed: 99/500
# Fraction completed: 100/500
# Fraction completed: 101/500
# Fraction completed: 102/500
# Fraction completed: 103/500
# Fraction completed: 104/500
# Fraction completed: 105/500
# Fraction completed: 106/500
# Fraction completed: 107/500
# Fraction completed: 108/500
# Fraction completed: 109/500
# Fraction completed: 110/500
# Fraction completed: 111/500
# Fraction completed: 112/500
# Fraction completed: 113/500
# Fraction completed: 114/500
# Fraction completed: 115/500
# Fraction completed: 116/500
# Fraction completed: 117/500
# Fraction completed: 118/500
# Fraction completed: 119/500
# Fraction completed: 120/500
# Fraction completed: 121/500
# Fraction completed: 122/500
# Fraction completed: 123/500
# Fraction completed: 124/500
# Fraction completed: 125/500
# Fraction completed: 126/500
# Fraction completed: 127/500
# Fraction completed: 128/500
# Fraction completed: 129/500
# Fraction completed: 130/500
# Fraction completed: 131/500
# Fraction completed: 132/500
# Fraction completed: 133/500
# Fraction completed: 134/500
# Fraction completed: 135/500
# Fraction completed: 136/500
# Fraction completed: 137/500
# Fraction completed: 138/500
# Fraction completed: 139/500
# Fraction completed: 140/500
# Fraction completed: 141/500
# Fraction completed: 142/500
# Fraction completed: 143/500
# Fraction completed: 144/500
# Fraction completed: 145/500
# Fraction completed: 146/500
# Fraction completed: 147/500
# Fraction completed: 148/500
# Fraction completed: 149/500
# Fraction completed: 150/500
# Fraction completed: 151/500
# Fraction completed: 152/500
# Fraction completed: 153/500
# Fraction completed: 154/500
# Fraction completed: 155/500
# Fraction completed: 156/500
# Fraction completed: 157/500
# Fraction completed: 158/500
# Fraction completed: 159/500
# Fraction completed: 160/500
# Fraction completed: 161/500
# Fraction completed: 162/500
# Fraction completed: 163/500
# Fraction completed: 164/500
# Fraction completed: 165/500
# Fraction completed: 166/500
# Fraction completed: 167/500
# Fraction completed: 168/500
# Fraction completed: 169/500
# Fraction completed: 170/500
# Fraction completed: 171/500
# Fraction completed: 172/500
# Fraction completed: 173/500
# Fraction completed: 174/500
# Fraction completed: 175/500
# Fraction completed: 176/500
# Fraction completed: 177/500
# Fraction completed: 178/500
# Fraction completed: 179/500
# Fraction completed: 180/500
# Fraction completed: 181/500
# Fraction completed: 182/500
# Fraction completed: 183/500
# Fraction completed: 184/500
# Fraction completed: 185/500
# Fraction completed: 186/500
# Fraction completed: 187/500
# Fraction completed: 188/500
# Fraction completed: 189/500
# Fraction completed: 190/500
# Fraction completed: 191/500
# Fraction completed: 192/500
# Fraction completed: 193/500
# Fraction completed: 194/500
# Fraction completed: 195/500
# Fraction completed: 196/500
# Fraction completed: 197/500
# Fraction completed: 198/500
# Fraction completed: 199/500
# Fraction completed: 200/500
# Fraction completed: 201/500
# Fraction completed: 202/500
# Fraction completed: 203/500
# Fraction completed: 204/500
# Fraction completed: 205/500
# Fraction completed: 206/500
# Fraction completed: 207/500
# Fraction completed: 208/500
# Fraction completed: 209/500
# Fraction completed: 210/500
# Fraction completed: 211/500
# Fraction completed: 212/500
# Fraction completed: 213/500
# Fraction completed: 214/500
# Fraction completed: 215/500
# Fraction completed: 216/500
# Fraction completed: 217/500
# Fraction completed: 218/500
# Fraction completed: 219/500
# Fraction completed: 220/500
# Fraction completed: 221/500
# Fraction completed: 222/500
# Fraction completed: 223/500
# Fraction completed: 224/500
# Fraction completed: 225/500
# Fraction completed: 226/500
# Fraction completed: 227/500
# Fraction completed: 228/500
# Fraction completed: 229/500
# Fraction completed: 230/500
# Fraction completed: 231/500
# Fraction completed: 232/500
# Fraction completed: 233/500
# Fraction completed: 234/500
# Fraction completed: 235/500
# Fraction completed: 236/500
# Fraction completed: 237/500
# Fraction completed: 238/500
# Fraction completed: 239/500
# Fraction completed: 240/500
# Fraction completed: 241/500
# Fraction completed: 242/500
# Fraction completed: 243/500
# Fraction completed: 244/500
# Fraction completed: 245/500
# Fraction completed: 246/500
# Fraction completed: 247/500
# Fraction completed: 248/500
# Fraction completed: 249/500
# Fraction completed: 250/500
# Fraction completed: 251/500
# Fraction completed: 252/500
# Fraction completed: 253/500
# Fraction completed: 254/500
# Fraction completed: 255/500
# Fraction completed: 256/500
# Fraction completed: 257/500
# Fraction completed: 258/500
# Fraction completed: 259/500
# Fraction completed: 260/500
# Fraction completed: 261/500
# Fraction completed: 262/500
# Fraction completed: 263/500
# Fraction completed: 264/500
# Fraction completed: 265/500
# Fraction completed: 266/500
# Fraction completed: 267/500
# Fraction completed: 268/500
# Fraction completed: 269/500
# Fraction completed: 270/500
# Fraction completed: 271/500
# Fraction completed: 272/500
# Fraction completed: 273/500
# Fraction completed: 274/500
# Fraction completed: 275/500
# Fraction completed: 276/500
# Fraction completed: 277/500
# Fraction completed: 278/500
# Fraction completed: 279/500
# Fraction completed: 280/500
# Fraction completed: 281/500
# Fraction completed: 282/500
# Fraction completed: 283/500
# Fraction completed: 284/500
# Fraction completed: 285/500
# Fraction completed: 286/500
# Fraction completed: 287/500
# Fraction completed: 288/500
# Fraction completed: 289/500
# Fraction completed: 290/500
# Fraction completed: 291/500
# Fraction completed: 292/500
# Fraction completed: 293/500
# Fraction completed: 294/500
# Fraction completed: 295/500
# Fraction completed: 296/500
# Fraction completed: 297/500
# Fraction completed: 298/500
# Fraction completed: 299/500
# Fraction completed: 300/500
# Fraction completed: 301/500
# Fraction completed: 302/500
# Fraction completed: 303/500
# Fraction completed: 304/500
# Fraction completed: 305/500
# Fraction completed: 306/500
# Fraction completed: 307/500
# Fraction completed: 308/500
# Fraction completed: 309/500
# Fraction completed: 310/500
# Fraction completed: 311/500
# Fraction completed: 312/500
# Fraction completed: 313/500
# Fraction completed: 314/500
# Fraction completed: 315/500
# Fraction completed: 316/500
# Fraction completed: 317/500
# Fraction completed: 318/500
# Fraction completed: 319/500
# Fraction completed: 320/500
# Fraction completed: 321/500
# Fraction completed: 322/500
# Fraction completed: 323/500
# Fraction completed: 324/500
# Fraction completed: 325/500
# Fraction completed: 326/500
# Fraction completed: 327/500
# Fraction completed: 328/500
# Fraction completed: 329/500
# Fraction completed: 330/500
# Fraction completed: 331/500
# Fraction completed: 332/500
# Fraction completed: 333/500
# Fraction completed: 334/500
# Fraction completed: 335/500
# Fraction completed: 336/500
# Fraction completed: 337/500
# Fraction completed: 338/500
# Fraction completed: 339/500
# Fraction completed: 340/500
# Fraction completed: 341/500
# Fraction completed: 342/500
# Fraction completed: 343/500
# Fraction completed: 344/500
# Fraction completed: 345/500
# Fraction completed: 346/500
# Fraction completed: 347/500
# Fraction completed: 348/500
# Fraction completed: 349/500
# Fraction completed: 350/500
# Fraction completed: 351/500
# Fraction completed: 352/500
# Fraction completed: 353/500
# Fraction completed: 354/500
# Fraction completed: 355/500
# Fraction completed: 356/500
# Fraction completed: 357/500
# Fraction completed: 358/500
# Fraction completed: 359/500
# Fraction completed: 360/500
# Fraction completed: 361/500
# Fraction completed: 362/500
# Fraction completed: 363/500
# Fraction completed: 364/500
# Fraction completed: 365/500
# Fraction completed: 366/500
# Fraction completed: 367/500
# Fraction completed: 368/500
# Fraction completed: 369/500
# Fraction completed: 370/500
# Fraction completed: 371/500
# Fraction completed: 372/500
# Fraction completed: 373/500
# Fraction completed: 374/500
# Fraction completed: 375/500
# Fraction completed: 376/500
# Fraction completed: 377/500
# Fraction completed: 378/500
# Fraction completed: 379/500
# Fraction completed: 380/500
# Fraction completed: 381/500
# Fraction completed: 382/500
# Fraction completed: 383/500
# Fraction completed: 384/500
# Fraction completed: 385/500
# Fraction completed: 386/500
# Fraction completed: 387/500
# Fraction completed: 388/500
# Fraction completed: 389/500
# Fraction completed: 390/500
# Fraction completed: 391/500
# Fraction completed: 392/500
# Fraction completed: 393/500
# Fraction completed: 394/500
# Fraction completed: 395/500
# Fraction completed: 396/500
# Fraction completed: 397/500
# Fraction completed: 398/500
# Fraction completed: 399/500
# Fraction completed: 400/500
# Fraction completed: 401/500
# Fraction completed: 402/500
# Fraction completed: 403/500
# Fraction completed: 404/500
# Fraction completed: 405/500
# Fraction completed: 406/500
# Fraction completed: 407/500
# Fraction completed: 408/500
# Fraction completed: 409/500
# Fraction completed: 410/500
# Fraction completed: 411/500
# Fraction completed: 412/500
# Fraction completed: 413/500
# Fraction completed: 414/500
# Fraction completed: 415/500
# Fraction completed: 416/500
# Fraction completed: 417/500
# Fraction completed: 418/500
# Fraction completed: 419/500
# Fraction completed: 420/500
# Fraction completed: 421/500
# Fraction completed: 422/500
# Fraction completed: 423/500
# Fraction completed: 424/500
# Fraction completed: 425/500
# Fraction completed: 426/500
# Fraction completed: 427/500
# Fraction completed: 428/500
# Fraction completed: 429/500
# Fraction completed: 430/500
# Fraction completed: 431/500
# Fraction completed: 432/500
# Fraction completed: 433/500
# Fraction completed: 434/500
# Fraction completed: 435/500
# Fraction completed: 436/500
# Fraction completed: 437/500
# Fraction completed: 438/500
# Fraction completed: 439/500
# Fraction completed: 440/500
# Fraction completed: 441/500
# Fraction completed: 442/500
# Fraction completed: 443/500
# Fraction completed: 444/500
# Fraction completed: 445/500
# Fraction completed: 446/500
# Fraction completed: 447/500
# Fraction completed: 448/500
# Fraction completed: 449/500
# Fraction completed: 450/500
# Fraction completed: 451/500
# Fraction completed: 452/500
# Fraction completed: 453/500
# Fraction completed: 454/500
# Fraction completed: 455/500
# Fraction completed: 456/500
# Fraction completed: 457/500
# Fraction completed: 458/500
# Fraction completed: 459/500
# Fraction completed: 460/500
# Fraction completed: 461/500
# Fraction completed: 462/500
# Fraction completed: 463/500
# Fraction completed: 464/500
# Fraction completed: 465/500
# Fraction completed: 466/500
# Fraction completed: 467/500
# Fraction completed: 468/500
# Fraction completed: 469/500
# Fraction completed: 470/500
# Fraction completed: 471/500
# Fraction completed: 472/500
# Fraction completed: 473/500
# Fraction completed: 474/500
# Fraction completed: 475/500
# Fraction completed: 476/500
# Fraction completed: 477/500
# Fraction completed: 478/500
# Fraction completed: 479/500
# Fraction completed: 480/500
# Fraction completed: 481/500
# Fraction completed: 482/500
# Fraction completed: 483/500
# Fraction completed: 484/500
# Fraction completed: 485/500
# Fraction completed: 486/500
# Fraction completed: 487/500
# Fraction completed: 488/500
# Fraction completed: 489/500
# Fraction completed: 490/500
# Fraction completed: 491/500
# Fraction completed: 492/500
# Fraction completed: 493/500
# Fraction completed: 494/500
# Fraction completed: 495/500
# Fraction completed: 496/500
# Fraction completed: 497/500
# Fraction completed: 498/500
# Fraction completed: 499/500

# %%
import json

def driving_dist(pat,clin):
    lat1, lon1 = pat[0], pat[1]
    lat2, lon2 = clin[0],clin[1]
    try:
        #raise requests.exceptions.ConnectionError('Throwing and exception here!')
        r = requests.get(f"http://router.project-osrm.org/route/v1/car/{lon1},{lat1};{lon2},{lat2}?overview=false""",timeout=to)
    except (requests.exceptions.ConnectionError,requests.exceptions.Timeout) as e:
        print(f"Error: {e}")
        r = 'No response'
    if r == 'No response':
        return 10e6
    else:
        try:
            #raise ValueError('this is wrong!')
            routes = json.loads(r.content)
            route_1 = routes.get("routes")
        except ValueError as e:
            print(f"Error: {e}")
            route_2 = 10e6
        if route_1 is None:
            route_2 = 10e6
        else:
            route_2 = route_1[0]['distance']
        return route_2/1000

drive_d = []
for p in range(0,1):
    print(f"Fraction completed: {p}/{patient_data.shape[0]}")
    #rad = 100
    while True:
        pat = list(patient_data.iloc[p][patient_data.iloc[0].index.isin(['Latitude','Longitude'])])
        lat_range, lon_range = neighbour_square(pat,rad)
        closer_clinics = clinics_in_square(lat_range,lon_range)
        if len(closer_clinics)>=sam: break
        else: rad+=inc

    clin_dist = {}
    for c in closer_clinics:
        clinic = clinic_data[clinic_data['Clinic ID']==c]
        clin = [list(clinic['Latitude'])[0],list(clinic['Longitude'])[0]]
        clin_dist[c] = driving_dist(pat,clin)
    clin_id = Val2Key(clin_dist,min(clin_dist.values()))
    drive_d.append([clin_id[0],min(clin_dist.values())])
    
drive_d

# %%
for i in range(194,195):
    print(i)

# %%
df

# %% [markdown]
# ### Supplementary

# %%
# import libraries
import pgeocode as geo

#pgeocode requirements
country = 'ca'
nomi = geo.Nominatim('ca')

def lat_long_finder(fsa):
    if np.isnan(nomi.query_postal_code(fsa)['latitude']):
        all_fsa = list(patient_data['FSA'])+list(clinic_data['FSA'])
        all_fsa.remove(fsa)
        for i in [1,2]:
            for j in all_fsa:
                if fsa[0:len(fsa)-i] in j:
                    fsa = j
                    break
            else:
                continue
            break
    FSA_location = nomi.query_postal_code(fsa)
    return [FSA_location['latitude'],FSA_location['longitude']]

# append patient_data
patient_data['Latitude'] = patient_data['FSA'].apply(lambda x: lat_long_finder(x)[0])
patient_data['Longitude'] = patient_data['FSA'].apply(lambda x: lat_long_finder(x)[1])

patient_data['Geocode'] = '('+patient_data['Latitude'].astype(str)+','+patient_data['Longitude'].astype(str)+')'

# append clinic_data
clinic_data['Latitude'] = clinic_data['FSA'].apply(lambda x: lat_long_finder(x)[0])
clinic_data['Longitude'] = clinic_data['FSA'].apply(lambda x: lat_long_finder(x)[1])

clinic_data['Geocode'] = '"'+clinic_data['Latitude'].astype(str)+','+clinic_data['Longitude'].astype(str)+'"'

# %%
# Haversine distance

from sklearn.metrics.pairwise import haversine_distances
from math import radians

def haversine_dist(pat,clin):
    pat_in_radians = [radians(_) for _ in pat]
    clin_in_radians = [radians(_) for _ in clin]
    dist = haversine_distances([pat_in_radians, clin_in_radians])
    dist * 6371000/1000  # multiply by Earth radius to get kilometers
    return dist[0][1]

haver_d = []
for p in range(patient_data.shape[0]):
    clin_dist = {}
    for c in range(clinic_data.shape[0]):
        pat = list(patient_data.iloc[p][patient_data.iloc[0].index.isin(['Latitude','Longitude'])])
        clin = list(clinic_data.iloc[c][clinic_data.iloc[0].index.isin(['Latitude','Longitude'])])
        clin_dist[clinic_data.iloc[c]['Clinic ID']] = haversine_dist(pat,clin)
    haver_d.append(Val2Key(clin_dist,min(clin_dist.values())))

closest_clinic_data = patient_data[['ID']].copy(deep=True)
closest_clinic_data['Haversine_Distance'] = haver_d

# %%
closest_clinic_data.head()

# %%
# driving distance

import requests
import json
import datetime

def driving_dist(pat,clin):
    # call the OSMR API
    lat1, lon1 = pat[0], pat[1]
    lat2, lon2 = clin[0],clin[1]
    r = requests.get(f"http://router.project-osrm.org/route/v1/car/{lon1},{lat1};{lon2},{lat2}?overview=false""")
    # then you load the response using the json libray
    # by default you get only one alternative so you access 0-th element of the `routes`
    routes = json.loads(r.content)
    route_1 = routes.get("routes")[0]
    #print(str(datetime.timedelta(seconds=route_1["duration"])))
    #print(f"Distance in km is: {route_1['distance']/1000}")
    return route_1['distance']/1000

start = datetime.datetime.now()
drive_d = []
for p in range(patient_data.shape[0]):
    clin_dist = {}
    for c in range(clinic_data.shape[0]):
        print(f"Patient: {patient_data.iloc[p]['ID']} Clinic: {clinic_data.iloc[c]['Clinic ID']}")
        pat = list(patient_data.iloc[p][patient_data.iloc[0].index.isin(['Latitude','Longitude'])])
        clin = list(clinic_data.iloc[c][clinic_data.iloc[0].index.isin(['Latitude','Longitude'])])
        clin_dist[clinic_data.iloc[c]['Clinic ID']] = driving_dist(pat,clin)
    drive_d.append(Val2Key(clin_dist,min(clin_dist.values())))

#closest_clinic_data = patient_data[['_ID']].copy(deep=True)
closest_clinic_data['Driving_Distance_BF'] = drive_d

print(f"Total runtime: {datetime.datetime.now()-start}")
print(f"Time per patient: {(datetime.datetime.now()-start)/patient_data.shape[0]}")

# %%
# find area around location of interest

from pygeodesy.ellipsoidalVincenty import LatLon 

def neighbour_square(latlon,rad):
    p = LatLon(latlon[0],latlon[1])
    for i in [0,90]:
        deg = i
        d1 = p.destination(rad*1000,deg)
        d2 = p.destination(rad*1000,deg+180)
        if i==0: lat_ran = [d1.lat,d2.lat]
        else: lon_ran = [d1.lon,d2.lon]
    return [lat_ran,lon_ran]

def clinics_in_square(lat_range,lon_range):
    near_clincs = []
    for c in range(clinic_data.shape[0]):
        clin = list(clinic_data.iloc[c][clinic_data.iloc[0].index.isin(['Latitude','Longitude'])])
        if min(lat_range)<=clin[0]<=max(lat_range) and min(lon_range)<=clin[1]<=max(lon_range):
            near_clincs.append(clinic_data.iloc[c]['Clinic ID'])
    return near_clincs

start = datetime.datetime.now()
drive_d = []
for p in range(patient_data.shape[0]):
    print(f"Fraction completed: {p}/{patient_data.shape[0]}")
    rad = 100
    while True:
        pat = list(patient_data.iloc[p][patient_data.iloc[0].index.isin(['Latitude','Longitude'])])
        lat_range, lon_range = neighbour_square(pat,rad)
        closer_clinics = clinics_in_square(lat_range,lon_range)
        if len(closer_clinics)>=3: break
        else: rad+=50

    clin_dist = {}
    for c in closer_clinics:
        clinic = clinic_data[clinic_data['Clinic ID']==c]
        clin = [list(clinic['Latitude'])[0],list(clinic['Longitude'])[0]]
        clin_dist[c] = driving_dist(pat,clin)
    drive_d.append(Val2Key(clin_dist,min(clin_dist.values())))
    
#closest_clinic_data = patient_data[['ID']].copy(deep=True)
#closest_clinic_data['Driving_Distance_Neighbourhood'] = drive_d

print(f"Total runtime: {datetime.datetime.now()-start}")
print(f"Time per patient: {(datetime.datetime.now()-start)/patient_data.shape[0]}")

# %%
closest_clinic_data['Driving_Distance_BF'].equals(closest_clinic_data['Driving_Distance_Neighbourhood'])
